# %% [markdown]
# # Ensemble Algorithm expalin
#  # Ensemble Algorithm is a method of machine learning where multiple models are trained on the same data and their
#  # predictions are combined to improve the overall performance of the model.
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
